# %%
# Load libraries
import os 
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st
import missingno as msno

# %%
extension = 'csv'
path = r'C:\Users\Justin\Data Science\NJ Transit\data'
all_files = glob.glob(path + "/*.csv")

li = []

# %%
#for file in all_files:
   # df = pd.read_csv(file, index_col=None)
    #li.append(df)
    
#frame = pd.concat(li, axis=0, ignore_index=True)
frame = pd.read_csv('data/2018_03.csv', index_col=None)
frame2 = pd.read_csv('data/2018_04.csv', index_col=None)
frame3 = pd.read_csv('data/2018_05.csv', index_col=None)

# %%
frame.head(20)
# Out:
#           date train_id  stop_sequence                   from  from_id  \
# 0   2018-03-01     3805            1.0  New York Penn Station      105
# 1   2018-03-01     3805            2.0  New York Penn Station      105
# 2   2018-03-01     3805            3.0     Secaucus Upper Lvl    38187
# 3   2018-03-01     3805            4.0    Newark Penn Station      107
# 4   2018-03-01     3805            5.0         Newark Airport    37953
# 5   2018-03-01     3805            6.0        North Elizabeth      109
# 6   2018-03-01     3805            7.0              Elizabeth       41
# 7   2018-03-01     3805            8.0                 Linden       70
# 8   2018-03-01     3805            9.0                 Rahway      127
# 9   2018-03-01     3805           10.0              Metropark       83
# 10  2018-03-01     3805           11.0               Metuchen       84
# 11  2018-03-01     3805           12.0                 Edison       38
# 12  2018-03-01     3805           13.0          New Brunswick      103
# 13  2018-03-01     3805           14.0          Jersey Avenue    32906
# 14  2018-03-01     3805           15.0     Princeton Junction      125
# 15  2018-03-01     3805           16.0               Hamilton    32905
# 16  2018-03-01     2312            1.0               Bay Head       13
# 17  2018-03-01     2312            2.0               Bay Head       13
# 18  2018-03-01     2312            3.0   Point Pleasant Beach      122
# 19  2018-03-01     2312            4.0              Manasquan       79
#
#                        to  to_id       scheduled_time          actual_time  \
# 0   New York Penn Station    105  2018-03-02 01:22:00  2018-03-02 01:21:05
# 1      Secaucus Upper Lvl  38187  2018-03-02 01:31:00  2018-03-02 01:31:08
# 2     Newark Penn Station    107  2018-03-02 01:40:00  2018-03-02 01:40:07
# 3          Newark Airport  37953  2018-03-02 01:45:00  2018-03-02 01:45:10
# 4         North Elizabeth    109  2018-03-02 01:49:00  2018-03-02 01:49:10
# 5               Elizabeth     41  2018-03-02 01:52:00  2018-03-02 01:52:01
# 6                  Linden     70  2018-03-02 01:58:00  2018-03-02 01:58:05
# 7                  Rahway    127  2018-03-02 02:02:00  2018-03-02 02:01:03
# 8               Metropark     83  2018-03-02 02:08:00  2018-03-02 02:08:00
# 9                Metuchen     84  2018-03-02 02:13:00  2018-03-02 02:13:10
# 10                 Edison     38  2018-03-02 02:18:00  2018-03-02 02:18:09
# 11          New Brunswick    103  2018-03-02 02:23:00  2018-03-02 02:23:09
# 12          Jersey Avenue  32906  2018-03-02 02:28:00  2018-03-02 02:28:08
# 13     Princeton Junction    125  2018-03-02 02:42:00  2018-03-02 02:33:08
# 14               Hamilton  32905  2018-03-02 02:49:00  2018-03-02 02:39:03
# 15                Trenton    148  2018-03-02 03:06:00  2018-03-02 02:42:00
# 16               Bay Head     13  2018-03-01 14:05:00  2018-03-01 14:06:03
# 17   Point Pleasant Beach    122  2018-03-01 14:09:00  2018-03-01 14:12:03
# 18              Manasquan     79  2018-03-01 14:14:00  2018-03-01 14:17:10
# 19            Spring Lake    141  2018-03-01 14:18:00  2018-03-01 14:21:02
#
#     delay_minutes     status              line        type
# 0        0.000000   departed  Northeast Corrdr  NJ Transit
# 1        0.133333   departed  Northeast Corrdr  NJ Transit
# 2        0.116667   departed  Northeast Corrdr  NJ Transit
# 3        0.166667   departed  Northeast Corrdr  NJ Transit
# 4        0.166667   departed  Northeast Corrdr  NJ Transit
# 5        0.016667   departed  Northeast Corrdr  NJ Transit
# 6        0.083333   departed  Northeast Corrdr  NJ Transit
# 7        0.000000   departed  Northeast Corrdr  NJ Transit
# 8        0.000000   departed  Northeast Corrdr  NJ Transit
# 9        0.166667   departed  Northeast Corrdr  NJ Transit
# 10       0.150000   departed  Northeast Corrdr  NJ Transit
# 11       0.150000   departed  Northeast Corrdr  NJ Transit
# 12       0.133333   departed  Northeast Corrdr  NJ Transit
# 13       0.000000   departed  Northeast Corrdr  NJ Transit
# 14       0.000000   departed  Northeast Corrdr  NJ Transit
# 15       0.000000  estimated  Northeast Corrdr  NJ Transit
# 16       1.050000   departed   No Jersey Coast  NJ Transit
# 17       3.050000   departed   No Jersey Coast  NJ Transit
# 18       3.166667   departed   No Jersey Coast  NJ Transit
# 19       3.033333   departed   No Jersey Coast  NJ Transit

# %%
frame.tail()
# Out:
#               date train_id  stop_sequence                 from  from_id  \
# 256503  2018-03-31     0534            2.0           Bay Street       14
# 256504  2018-03-31     0534            3.0           Glen Ridge       50
# 256505  2018-03-31     0534            4.0           Bloomfield       19
# 256506  2018-03-31     0534            5.0    Watsessing Avenue      154
# 256507  2018-03-31     0534            6.0  Newark Broad Street      106
#
#                          to  to_id       scheduled_time          actual_time  \
# 256503           Glen Ridge     50  2018-03-31 19:02:00  2018-03-31 19:05:07
# 256504           Bloomfield     19  2018-03-31 19:05:00  2018-03-31 19:08:06
# 256505    Watsessing Avenue    154  2018-03-31 19:07:00  2018-03-31 19:10:11
# 256506  Newark Broad Street    106  2018-03-31 19:13:00  2018-03-31 19:21:02
# 256507              Hoboken     63  2018-03-31 19:38:00  2018-03-31 19:37:00
#
#         delay_minutes     status               line        type
# 256503       3.116667   departed  Montclair-Boonton  NJ Transit
# 256504       3.100000   departed  Montclair-Boonton  NJ Transit
# 256505       3.183333   departed  Montclair-Boonton  NJ Transit
# 256506       8.033333   departed  Montclair-Boonton  NJ Transit
# 256507       0.000000  estimated  Montclair-Boonton  NJ Transit

# %%
frame.describe()
# Out:
#        stop_sequence        from_id          to_id  delay_minutes
# count  243028.000000  256508.000000  256508.000000  243028.000000
# mean        7.981661    4150.178474    4159.246971       3.548316
# std         5.074539   11708.973053   11718.667560       6.680843
# min         1.000000       1.000000       1.000000       0.000000
# 25%         4.000000      58.000000      58.000000       0.233333
# 50%         7.000000     104.000000     104.000000       2.100000
# 75%        11.000000     136.000000     136.000000       4.116667
# max        26.000000   43599.000000   43599.000000     111.183333

# %%
frame.shape
# Out:
# (256508, 13)

# %%
numeric_features = frame.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['stop_sequence', 'from_id', 'to_id', 'delay_minutes'], dtype='object')

# %%
categorical_features = frame.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['date', 'train_id', 'from', 'to', 'scheduled_time', 'actual_time',
#        'status', 'line', 'type'],
#       dtype='object')

# %%
msno.matrix(frame.sample(1000))

# %%
msno.bar(frame.sample(1000))

# %%
msno.dendrogram(frame)

# %%
frame.skew()
# Out:
# stop_sequence    0.609826
# from_id          2.547349
# to_id            2.542938
# delay_minutes    6.711687
# dtype: float64

# %%
frame.kurt()
# Out:
# stop_sequence    -0.178707
# from_id           4.531273
# to_id             4.509065
# delay_minutes    64.439162
# dtype: float64

# %%
# Remove rows where we have no delay_minutes value
frame = frame.dropna(subset=['delay_minutes'])
frame2 = frame2.dropna(subset=['delay_minutes'])
frame3 = frame3.dropna(subset=['delay_minutes'])

# %%
y = frame['delay_minutes']

plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)

plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)

plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Justin\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:3421: RuntimeWarning: divide by zero encountered in log
#   trm = _norm_pdf(a + b * np.log(x + np.sqrt(x2+1)))

# %%
sns.distplot(frame.skew(), color='blue', axlabel='Skewness')

# %%
plt.figure(figsize = (12,8))
sns.distplot(frame.kurt(), color='r', axlabel='Kurtosis', norm_hist=False, kde=True, rug=False)
plt.show()

# %%
plt.hist(frame['delay_minutes'], orientation='vertical', histtype='bar', color='blue')
plt.show()

# %%
correlation = numeric_features.corr()
print(correlation['delay_minutes'].sort_values(ascending=False), '\n')
# Out:
# delay_minutes    1.000000
# stop_sequence    0.079041
# to_id            0.015533
# from_id          0.000823
# Name: delay_minutes, dtype: float64

# %%
f, ax = plt.subplots(figsize = (15, 15))
sns.heatmap(correlation, square=True, linewidths=0.5, annot=True)
plt.show()

# %%
sns.set()
columns = ['delay_minutes', 'stop_sequence', 'to_id', 'from_id']
sns.pairplot(frame[numeric_features.columns], size=2, kind='scatter', diag_kind='kde')
plt.show()
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
fig, ((ax1, ax2, ax3)) = plt.subplots(nrows=1, ncols=3, figsize=(14,10))

stop_sequence_scatter = pd.concat([frame['delay_minutes'], frame['stop_sequence']], axis=1)
sns.regplot(x='stop_sequence', y='delay_minutes', data=stop_sequence_scatter, scatter=True, fit_reg=True, ax=ax1)

from_id_scatter = pd.concat([frame['delay_minutes'], frame['from_id']], axis=1)
sns.regplot(x='from_id', y='delay_minutes', data=from_id_scatter, scatter=True, fit_reg=True, ax=ax2)

to_id_scatter = pd.concat([frame['delay_minutes'], frame['to_id']], axis=1)
sns.regplot(x='to_id', y='delay_minutes', data=to_id_scatter, scatter=True, fit_reg=True, ax=ax3)

# %%
delay_minutes_stop_sequence = frame.pivot_table(index='stop_sequence', values='delay_minutes', aggfunc=np.median)
delay_minutes_stop_sequence.plot(kind='bar', color='blue')
plt.xlabel('stop_sequence')
plt.ylabel('median delay minutes')
plt.show()

# %%
var = 'stop_sequence'
data = pd.concat([frame['delay_minutes'], frame[var]], axis=1)
f, ax = plt.subplots(figsize=(12,8))
fig = sns.boxplot(x=var, y='delay_minutes', data=data)
fig.axis(ymin=0, ymax=150)
# Out:
# (-0.5, 25.5, 0, 150)

# %%
var = 'line'
data = pd.concat([frame['delay_minutes'], frame[var]], axis=1)
f, ax = plt.subplots(figsize=(12,8))
fig = sns.boxplot(x=var, y='delay_minutes', data=data)
fig.axis(ymin=0, ymax=20);
xt = plt.xticks(rotation=45)

# %%
var = 'from_id'
data = pd.concat([frame['delay_minutes'], frame[var]], axis=1)
f, ax = plt.subplots(figsize=(12,8))
fig = sns.boxplot(x=var, y='delay_minutes', data=data)
fig.axis(ymin=0, ymax=20);
xt = plt.xticks(rotation=90)

# %%
# see how date effects delay_minutes
frame['date'] = pd.to_datetime(frame['date'])
frame2['date'] = pd.to_datetime(frame2['date'])
frame3['date'] = pd.to_datetime(frame3['date'])

plt.plot_date(x=frame['date'], y=frame['delay_minutes'], fmt='r-')
plt.plot_date(x=frame2['date'], y=frame2['delay_minutes'], fmt='r-')
plt.plot_date(x=frame3['date'], y=frame3['delay_minutes'], fmt='r-')

plt.xticks(rotation=90)
# Out:
# (array([736754., 736768., 736782., 736785., 736799., 736813., 736815.,
#         736829., 736843., 736846.]), <a list of 10 Text xticklabel objects>)

# %%
categorical_features
remove_time = categorical_features.remove('date')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-a578f0bb23ab> in <module>
#       1 categorical_features
# ----> 2 remove_time = categorical_features.remove('date')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'remove'

# %%
no_time_features = frame[['status', 'line', 'type']]
no_time_features.columns
# Out:
# Index(['status', 'line', 'type'], dtype='object')

# %%
for c in no_time_features:
    frame[c] = frame[c].astype('category')
    if frame[c].isnull().any():
        frame[c] = frame[c].cat.add_categories(['MISSING'])
        frame[c] = frame[c].fillna('MISSING')
        
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
    
f = pd.melt(frame, id_vars=['delay_minutes'], value_vars=no_time_features)
g = sns.FacetGrid(f, col='variable', col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, 'value', 'delay_minutes')
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
frame['long_delay'] = frame['delay_minutes'] > 5
frame.groupby('line')['long_delay'].mean().sort_values(ascending=False).plot(kind='bar')

# %%
x= frame.groupby(['line', 'status']).size().unstack()
x['cancelled']/(x['departed']+x['estimated'])
# Out:
# line
# Atl. City Line       0.019146
# Bergen Co. Line      0.014206
# Gladstone Branch     0.019113
# Main Line            0.013687
# Montclair-Boonton    0.024483
# Morristown Line      0.032697
# No Jersey Coast      0.009115
# Northeast Corrdr     0.015558
# Pascack Valley       0.022476
# Princeton Shuttle         NaN
# Raritan Valley       0.011177
# dtype: float64

# %%
x['cancelled']
# Out:
# line
# Atl. City Line        117.0
# Bergen Co. Line       286.0
# Gladstone Branch      448.0
# Main Line             298.0
# Montclair-Boonton     458.0
# Morristown Line      1161.0
# No Jersey Coast       337.0
# Northeast Corrdr      577.0
# Pascack Valley        332.0
# Princeton Shuttle       NaN
# Raritan Valley        223.0
# Name: cancelled, dtype: float64

# %%
ax = frame.groupby('stop_sequence')['delay_minutes'].mean().plot()
ax.set_ylabel('average delay_minutes')
# Out:
# Text(0, 0.5, 'average delay_minutes')

# %%
frame.groupby('from')['delay_minutes'].mean().sort_values(ascending=False).head(10)
# Out:
# from
# Sloatsburg          6.185764
# Cherry Hill         6.145617
# Harriman            5.969284
# Atco                5.958213
# Lindenwold          5.955491
# Egg Harbor City     5.720014
# Tuxedo              5.414479
# Pennsauken          5.366040
# Rahway              4.867562
# Aberdeen-Matawan    4.780735
# Name: delay_minutes, dtype: float64

# %%
frame.groupby('to')['delay_minutes'].mean().sort_values(ascending=False).head(10)
# Out:
# to
# Tuxedo                7.615451
# Lindenwold            5.446580
# Hammonton             5.311946
# Cherry Hill           5.071845
# Hazlet                4.885231
# Pennsauken            4.868618
# Aberdeen-Matawan      4.851820
# Perth Amboy           4.819064
# Metropark             4.771738
# Secaucus Upper Lvl    4.740429
# Name: delay_minutes, dtype: float64

# %%
x = frame.groupby('date')['delay_minutes'].mean()
fig, ax = plt.subplots()
fig.set_size_inches(20,8)
fig.autofmt_xdate()
ax.plot(x)
ax.set_ylabel('average delay_minutes')
plt.show()
