# %%
# Load libraries
import os 
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st
import missingno as msno

# %%
extension = 'csv'
path = r'C:\Users\Justin\Data Science\NJ Transit\data'
all_files = glob.glob(path + "/*.csv")

li = []

# %%
for file in all_files:
    df = pd.read_csv(file, index_col=None)
    li.append(df)
    
frame = pd.concat(li, axis=0, ignore_index=True)
#frame = pd.read_csv('data/2018_03.csv', index_col=None)
#frame2 = pd.read_csv('data/2018_04.csv', index_col=None)
#frame3 = pd.read_csv('data/2018_05.csv', index_col=None)

# %%
x = frame.groupby('line')['stop_sequence'].mean().sort_values(ascending=False)
x.mean()
# Out:
# 7.388493716096957

# %%
frame.head(20)
# Out:
#           date train_id  stop_sequence                   from  from_id  \
# 0   2018-03-01     3805            1.0  New York Penn Station    105.0
# 1   2018-03-01     3805            2.0  New York Penn Station    105.0
# 2   2018-03-01     3805            3.0     Secaucus Upper Lvl  38187.0
# 3   2018-03-01     3805            4.0    Newark Penn Station    107.0
# 4   2018-03-01     3805            5.0         Newark Airport  37953.0
# 5   2018-03-01     3805            6.0        North Elizabeth    109.0
# 6   2018-03-01     3805            7.0              Elizabeth     41.0
# 7   2018-03-01     3805            8.0                 Linden     70.0
# 8   2018-03-01     3805            9.0                 Rahway    127.0
# 9   2018-03-01     3805           10.0              Metropark     83.0
# 10  2018-03-01     3805           11.0               Metuchen     84.0
# 11  2018-03-01     3805           12.0                 Edison     38.0
# 12  2018-03-01     3805           13.0          New Brunswick    103.0
# 13  2018-03-01     3805           14.0          Jersey Avenue  32906.0
# 14  2018-03-01     3805           15.0     Princeton Junction    125.0
# 15  2018-03-01     3805           16.0               Hamilton  32905.0
# 16  2018-03-01     2312            1.0               Bay Head     13.0
# 17  2018-03-01     2312            2.0               Bay Head     13.0
# 18  2018-03-01     2312            3.0   Point Pleasant Beach    122.0
# 19  2018-03-01     2312            4.0              Manasquan     79.0
#
#                        to    to_id       scheduled_time          actual_time  \
# 0   New York Penn Station    105.0  2018-03-02 01:22:00  2018-03-02 01:21:05
# 1      Secaucus Upper Lvl  38187.0  2018-03-02 01:31:00  2018-03-02 01:31:08
# 2     Newark Penn Station    107.0  2018-03-02 01:40:00  2018-03-02 01:40:07
# 3          Newark Airport  37953.0  2018-03-02 01:45:00  2018-03-02 01:45:10
# 4         North Elizabeth    109.0  2018-03-02 01:49:00  2018-03-02 01:49:10
# 5               Elizabeth     41.0  2018-03-02 01:52:00  2018-03-02 01:52:01
# 6                  Linden     70.0  2018-03-02 01:58:00  2018-03-02 01:58:05
# 7                  Rahway    127.0  2018-03-02 02:02:00  2018-03-02 02:01:03
# 8               Metropark     83.0  2018-03-02 02:08:00  2018-03-02 02:08:00
# 9                Metuchen     84.0  2018-03-02 02:13:00  2018-03-02 02:13:10
# 10                 Edison     38.0  2018-03-02 02:18:00  2018-03-02 02:18:09
# 11          New Brunswick    103.0  2018-03-02 02:23:00  2018-03-02 02:23:09
# 12          Jersey Avenue  32906.0  2018-03-02 02:28:00  2018-03-02 02:28:08
# 13     Princeton Junction    125.0  2018-03-02 02:42:00  2018-03-02 02:33:08
# 14               Hamilton  32905.0  2018-03-02 02:49:00  2018-03-02 02:39:03
# 15                Trenton    148.0  2018-03-02 03:06:00  2018-03-02 02:42:00
# 16               Bay Head     13.0  2018-03-01 14:05:00  2018-03-01 14:06:03
# 17   Point Pleasant Beach    122.0  2018-03-01 14:09:00  2018-03-01 14:12:03
# 18              Manasquan     79.0  2018-03-01 14:14:00  2018-03-01 14:17:10
# 19            Spring Lake    141.0  2018-03-01 14:18:00  2018-03-01 14:21:02
#
#     delay_minutes     status              line        type
# 0        0.000000   departed  Northeast Corrdr  NJ Transit
# 1        0.133333   departed  Northeast Corrdr  NJ Transit
# 2        0.116667   departed  Northeast Corrdr  NJ Transit
# 3        0.166667   departed  Northeast Corrdr  NJ Transit
# 4        0.166667   departed  Northeast Corrdr  NJ Transit
# 5        0.016667   departed  Northeast Corrdr  NJ Transit
# 6        0.083333   departed  Northeast Corrdr  NJ Transit
# 7        0.000000   departed  Northeast Corrdr  NJ Transit
# 8        0.000000   departed  Northeast Corrdr  NJ Transit
# 9        0.166667   departed  Northeast Corrdr  NJ Transit
# 10       0.150000   departed  Northeast Corrdr  NJ Transit
# 11       0.150000   departed  Northeast Corrdr  NJ Transit
# 12       0.133333   departed  Northeast Corrdr  NJ Transit
# 13       0.000000   departed  Northeast Corrdr  NJ Transit
# 14       0.000000   departed  Northeast Corrdr  NJ Transit
# 15       0.000000  estimated  Northeast Corrdr  NJ Transit
# 16       1.050000   departed   No Jersey Coast  NJ Transit
# 17       3.050000   departed   No Jersey Coast  NJ Transit
# 18       3.166667   departed   No Jersey Coast  NJ Transit
# 19       3.033333   departed   No Jersey Coast  NJ Transit

# %%
frame.tail()
# Out:
#                date train_id  stop_sequence                 from  from_id  \
# 3428997  2019-04-30     1629            5.0               Nanuet    100.0
# 3428998  2019-04-30    A2124            NaN         Philadelphia      1.0
# 3428999  2019-04-30    A2124            NaN         Philadelphia      1.0
# 3429000  2019-04-30    A2124            NaN            Metropark     83.0
# 3429001  2019-04-30    A2124            NaN  Newark Penn Station    107.0
#
#                             to  to_id       scheduled_time  \
# 3428997          Spring Valley  142.0  2019-04-30 18:25:00
# 3428998           Philadelphia    1.0                  NaN
# 3428999              Metropark   83.0                  NaN
# 3429000    Newark Penn Station  107.0                  NaN
# 3429001  New York Penn Station  105.0                  NaN
#
#                  actual_time  delay_minutes     status            line  \
# 3428997  2019-04-30 18:27:00            2.0  estimated  Pascack Valley
# 3428998  2019-04-30 19:28:49            NaN   departed   ACELA EXPRESS
# 3428999  2019-04-30 20:16:23            NaN   departed   ACELA EXPRESS
# 3429000  2019-04-30 20:30:53            NaN   departed   ACELA EXPRESS
# 3429001  2019-04-30 20:49:04            NaN   departed   ACELA EXPRESS
#
#                type
# 3428997  NJ Transit
# 3428998      Amtrak
# 3428999      Amtrak
# 3429000      Amtrak
# 3429001      Amtrak

# %%
frame.describe()
# Out:
#        stop_sequence       from_id         to_id  delay_minutes
# count   3.150284e+06  3.428111e+06  3.428111e+06   3.150284e+06
# mean    8.081979e+00  4.191632e+03  4.203952e+03   4.058194e+00
# std     5.087855e+00  1.174142e+04  1.175508e+04   6.212329e+00
# min     1.000000e+00  1.000000e+00  1.000000e+00   0.000000e+00
# 25%     4.000000e+00  5.900000e+01  5.900000e+01   1.066667e+00
# 50%     7.000000e+00  1.050000e+02  1.050000e+02   2.300000e+00
# 75%     1.200000e+01  1.360000e+02  1.360000e+02   5.066667e+00
# max     2.600000e+01  4.359900e+04  4.359900e+04   3.260000e+02

# %%
frame.shape
# Out:
# (3429002, 13)

# %%
numeric_features = frame.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['stop_sequence', 'from_id', 'to_id', 'delay_minutes'], dtype='object')

# %%
categorical_features = frame.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['date', 'train_id', 'from', 'to', 'scheduled_time', 'actual_time',
#        'status', 'line', 'type'],
#       dtype='object')

# %%
msno.matrix(frame.sample(1000))

# %%
msno.bar(frame.sample(1000))

# %%
msno.dendrogram(frame)

# %%
frame.skew()
# Out:
# stop_sequence    0.602842
# from_id          2.523344
# to_id            2.517520
# delay_minutes    5.797532
# dtype: float64

# %%
frame.kurt()
# Out:
# stop_sequence    -0.169474
# from_id           4.406279
# to_id             4.377140
# delay_minutes    65.492690
# dtype: float64

# %%
# Remove rows where we have no delay_minutes value
frame = frame.dropna(subset=['delay_minutes'])

# %%
y = frame['delay_minutes']

plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)

plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)

plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(frame.skew(), color='blue', axlabel='Skewness')
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (12,8))
sns.distplot(frame.kurt(), color='r', axlabel='Kurtosis', norm_hist=False, kde=True, rug=False)
plt.show()

# %%
plt.hist(frame['delay_minutes'], orientation='vertical', histtype='bar', color='blue')
plt.show()

# %%
correlation = numeric_features.corr()
print(correlation['delay_minutes'].sort_values(ascending=False), '\n')
# Out:
# delay_minutes    1.000000
# stop_sequence    0.083680
# to_id            0.012695
# from_id         -0.009690
# Name: delay_minutes, dtype: float64

# %%
f, ax = plt.subplots(figsize = (15, 15))
sns.heatmap(correlation, square=True, linewidths=0.5, annot=True)
plt.show()

# %%
sns.set()
columns = ['delay_minutes', 'stop_sequence', 'to_id', 'from_id']
sns.pairplot(frame[numeric_features.columns], size=2, kind='scatter', diag_kind='kde')
plt.show()
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Justin\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\Justin\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
fig, ((ax1, ax2, ax3)) = plt.subplots(nrows=1, ncols=3, figsize=(14,10))

stop_sequence_scatter = pd.concat([frame['delay_minutes'], frame['stop_sequence']], axis=1)
sns.regplot(x='stop_sequence', y='delay_minutes', data=stop_sequence_scatter, scatter=True, fit_reg=True, ax=ax1)

from_id_scatter = pd.concat([frame['delay_minutes'], frame['from_id']], axis=1)
sns.regplot(x='from_id', y='delay_minutes', data=from_id_scatter, scatter=True, fit_reg=True, ax=ax2)

to_id_scatter = pd.concat([frame['delay_minutes'], frame['to_id']], axis=1)
sns.regplot(x='to_id', y='delay_minutes', data=to_id_scatter, scatter=True, fit_reg=True, ax=ax3)

# %%
delay_minutes_stop_sequence = frame.pivot_table(index='stop_sequence', values='delay_minutes', aggfunc=np.median)
delay_minutes_stop_sequence.plot(kind='bar', color='blue')
plt.xlabel('stop_sequence')
plt.ylabel('median delay minutes')
plt.show()

# %%
var = 'stop_sequence'
data = pd.concat([frame['delay_minutes'], frame[var]], axis=1)
f, ax = plt.subplots(figsize=(12,8))
fig = sns.boxplot(x=var, y='delay_minutes', data=data)
fig.axis(ymin=0, ymax=150)
# Out:
# (-0.5, 25.5, 0, 150)

# %%
var = 'line'
data = pd.concat([frame['delay_minutes'], frame[var]], axis=1)
f, ax = plt.subplots(figsize=(12,8))
fig = sns.boxplot(x=var, y='delay_minutes', data=data)
fig.axis(ymin=0, ymax=20);
xt = plt.xticks(rotation=45)

# %%
var = 'from_id'
data = pd.concat([frame['delay_minutes'], frame[var]], axis=1)
f, ax = plt.subplots(figsize=(12,8))
fig = sns.boxplot(x=var, y='delay_minutes', data=data)
fig.axis(ymin=0, ymax=20);
xt = plt.xticks(rotation=90)

# %%
# see how date effects delay_minutes
frame['date'] = pd.to_datetime(frame['date'])
plt.plot_date(x=frame['date'], y=frame['delay_minutes'], fmt='r-')
plt.xticks(rotation=90)
# Out:
# (array([736754., 736815., 736876., 736938., 736999., 737060., 737119.,
#         737180.]), <a list of 8 Text xticklabel objects>)

# %%
no_time_features = frame[['status', 'line', 'type']]
no_time_features.columns
# Out:
# Index(['status', 'line', 'type'], dtype='object')

# %%
for c in no_time_features:
    frame[c] = frame[c].astype('category')
    if frame[c].isnull().any():
        frame[c] = frame[c].cat.add_categories(['MISSING'])
        frame[c] = frame[c].fillna('MISSING')
        
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
    
f = pd.melt(frame, id_vars=['delay_minutes'], value_vars=no_time_features)
g = sns.FacetGrid(f, col='variable', col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, 'value', 'delay_minutes')
# Out:
# C:\Users\Justin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
frame['long_delay'] = frame['delay_minutes'] > 5
frame.groupby('line')['long_delay'].mean().sort_values(ascending=False).plot(kind='bar')

# %%
x= frame.groupby(['line', 'status']).size().unstack()
x['cancelled']/(x['departed']+x['estimated'])
# Out:
# line
# Atl. City Line       0.011612
# Bergen Co. Line      0.009437
# Gladstone Branch     0.025498
# Main Line            0.007891
# Montclair-Boonton    0.017503
# Morristown Line      0.024140
# No Jersey Coast      0.013902
# Northeast Corrdr     0.013058
# Pascack Valley       0.009361
# Princeton Shuttle         NaN
# Raritan Valley       0.008156
# dtype: float64

# %%
x['cancelled']
# Out:
# line
# Atl. City Line         393.0
# Bergen Co. Line       2661.0
# Gladstone Branch      7342.0
# Main Line             2360.0
# Montclair-Boonton     4686.0
# Morristown Line      11761.0
# No Jersey Coast       6452.0
# Northeast Corrdr      6712.0
# Pascack Valley        1914.0
# Princeton Shuttle        NaN
# Raritan Valley        1880.0
# Name: cancelled, dtype: float64

# %%
ax = frame.groupby('stop_sequence')['delay_minutes'].mean().plot()
ax.set_ylabel('average delay_minutes')
# Out:
# Text(0, 0.5, 'average delay_minutes')

# %%
frame.groupby('from')['delay_minutes'].mean().sort_values(ascending=False).head(10)
# Out:
# from
# Secaucus Concourse    8.170000
# Monmouth Park         7.473215
# Harriman              6.577968
# Cherry Hill           6.440567
# Lindenwold            6.320886
# Atco                  6.134823
# Egg Harbor City       5.877944
# Aberdeen-Matawan      5.826064
# North Branch          5.817665
# Wayne-Route 23        5.778489
# Name: delay_minutes, dtype: float64

# %%
frame.groupby('to')['delay_minutes'].mean().sort_values(ascending=False).head(10)
# Out:
# to
# Tuxedo                      5.877632
# Lindenwold                  5.868428
# White House                 5.856180
# Aberdeen-Matawan            5.853610
# Hazlet                      5.836350
# Salisbury Mills-Cornwall    5.811459
# Mountain View               5.775137
# Middletown NJ               5.528177
# Westfield                   5.520674
# Hammonton                   5.465668
# Name: delay_minutes, dtype: float64

# %%
x = frame.groupby('date')['delay_minutes'].mean()
fig, ax = plt.subplots()
fig.set_size_inches(20,8)
fig.autofmt_xdate()
ax.plot(x)
ax.set_ylabel('average delay_minutes')
plt.show()

# %%
frame.scheduled_time = pd.to_datetime(frame.scheduled_time)
frame['time'] = frame.scheduled_time.dt.time

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 8)
x = frame.groupby('time')['delay_minutes'].mean()
ax.plot(x)
ax.set_ylabel('average delay_minutes')
plt.show()

# %%
x.sort_values(ascending=False).head(5)
# Out:
# time
# 03:00:00    10.487500
# 03:07:00    10.462010
# 03:04:00    10.296078
# 02:56:00    10.232353
# 03:13:00    10.193873
# Name: delay_minutes, dtype: float64

# %%
x = frame.groupby(['date', 'status']).size().unstack()
x = (x['cancelled']/(x['departed']+x['estimated']))

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 8)
ax.plot(x)
ax.set_ylabel('cancellation rate')
plt.show()

# %%
x.sort_values(ascending=False).head(5)
# Out:
# date
# 2018-03-08    0.391646
# 2018-11-16    0.280079
# 2018-03-07    0.166506
# 2019-02-25    0.122171
# 2019-02-21    0.121777
# dtype: float64

# %%
x = frame.groupby(['time', 'status']).size().unstack()
x = (x['cancelled']/(x['departed']+x['estimated']))

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,8)
ax.plot(x)
ax.set_ylabel('cancellation rate')
plt.show()
